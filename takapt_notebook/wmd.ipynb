# %%
import pandas as pd
import numpy as np
import nltk
from collections import Counter
from nltk.corpus import stopwords
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.optimize import minimize
stops = set(stopwords.words("english"))
import xgboost as xgb
from sklearn.cross_validation import train_test_split
import multiprocessing
import difflib
from gensim.models import KeyedVectors
# Out:
# /home/takaya/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
features = [
#     'clean_q1_tokenized',
#     'clean_q2_tokenized',
#     'clean_q1_stem',
#     'clean_q2_stem',
#     'clean_q1_pos_tagged',
#     'clean_q2_pos_tagged',
    'clean_q1_lemmatized',
    'clean_q2_lemmatized',
#     'clean_q1_lemmatized_stem',
#     'clean_q2_lemmatized_stem'
]

# %%
def read_data(t, features):
    data = pd.read_csv('../input/{}.csv'.format(t))
    for feature in features:
        data = pd.merge(data, pd.read_pickle('../feature/{}_{}.pkl'.format(t, feature)))
    data.fillna(0.0)
    return data

# %%
train = read_data('train', features)#[:1000]
test = read_data('test', features)#[:1000]

# %%
model = KeyedVectors.load_word2vec_format('../data/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
from multiprocessing import Pool

# %%
def parallel(df, func):
    splitted_df = np.array_split(df, 32)
    pool = Pool(6)
    df = pd.concat(pool.map(func, splitted_df))
    pool.close()
    pool.join()
    return df

# %%
def wmd(df):
    def gao(row):
        a = [w for w in row.clean_q1_lemmatized if w not in stops and w in model]
        b = [w for w in row.clean_q2_lemmatized if w not in stops and w in model]
        if len(a) == 0 or len(b) == 0:
            return 10.0
        return model.wmdistance(a, b)

    df['clean_lemm_wmd'] = df.apply(gao, axis=1)
    return df

# %%
train = parallel(train, wmd)

# %%
test = parallel(test, wmd)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['figure.figsize'] = (15.0, 15.0)

# %%
plt.hist(train.clean_lemm_wmd[train['is_duplicate'] == 0], bins=20, normed=True, label='0')
plt.hist(train.clean_lemm_wmd[train['is_duplicate'] == 1], bins=20, normed=True, label='1', alpha=0.7)
None

# %%
print(',\n'.join(map(lambda s: "'{}'".format(s), (col for col in train.columns if col.startswith('clean_')))))
# Out:
# 'clean_q1_lemmatized',
# 'clean_q2_lemmatized',
# 'clean_lemm_wmd'

# %%
features_to_save = [
    'clean_lemm_wmd',
]

# %%
train
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# 5            5      11      12
# 6            6      13      14
# 7            7      15      16
# 8            8      17      18
# 9            9      19      20
# 10          10      21      22
# 11          11      23      24
# 12          12      25      26
# 13          13      27      28
# 14          14      29      30
# 15          15      31      32
# 16          16      33      34
# 17          17      35      36
# 18          18      37      38
# 19          19      39      40
# 20          20      41      42
# 21          21      43      44
# 22          22      45      46
# 23          23      47      48
# 24          24      49      50
# 25          25      51      52
# 26          26      53      54
# 27          27      55      56
# 28          28      57      58
# 29          29      59      60
# ...        ...     ...     ...
# 404260  404260  182494     691
# 404261  404261  281150  124172
# 404262  404262  537905  466328
# 404263  404263  375195  537906
# 404264  404264  537907  537908
# 404265  404265   25994   16064
# 404266  404266  155813  146284
# 404267  404267   20171  290649
# 404268  404268  537909  537910
# 404269  404269  537911  349794
# 404270  404270  537912   35364
# 404271  404271  537913  537914
# 404272  404272  128018   14005
# 404273  404273  537915  537916
# 404274  404274  178643   87385
# 404275  404275   97922  537917
# 404276  404276   24305  308365
# 404277  404277  355668  537918
# 404278  404278  537919  169786
# 404279  404279  537920  537921
# 404280  404280  537922  537923
# 404281  404281   99131   81495
# 404282  404282    1931   16773
# 404283  404283  537924  537925
# 404284  404284  537926  537927
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# 5       Astrology: I am a Capricorn Sun Cap moon and c...
# 6                                     Should I buy tiago?
# 7                          How can I be a good geologist?
# 8                         When do you use シ instead of し?
# 9       Motorola (company): Can I hack my Charter Moto...
# 10      Method to find separation of slits using fresn...
# 11            How do I read and find my YouTube comments?
# 12                   What can make Physics easy to learn?
# 13            What was your first sexual experience like?
# 14      What are the laws to change your status from a...
# 15      What would a Trump presidency mean for current...
# 16                           What does manipulation mean?
# 17      Why do girls want to be friends with the guy t...
# 18      Why are so many Quora users posting questions ...
# 19      Which is the best digital marketing institutio...
# 20                             Why do rockets look white?
# 21                  What's causing someone to be jealous?
# 22        What are the questions should not ask on Quora?
# 23                               How much is 30 kV in HP?
# 24      What does it mean that every time I look at th...
# 25      What are some tips on making it through the jo...
# 26                               What is web application?
# 27      Does society place too much importance on sports?
# 28                 What is best way to make money online?
# 29                 How should I prepare for CA final law?
# ...                                                   ...
# 404260                   Which phone is best under 12000?
# 404261  Who is the overall most popular Game of Throne...
# 404262          How do you troubleshoot a Toshiba laptop?
# 404263  How does the burning of fossil fuels contribut...
# 404264  Is it safe to store an external battery power ...
# 404265                  How can I gain weight on my body?
# 404266  What is the green dot next to the phone icon o...
# 404267  What are the causes of the fall of the Roman E...
# 404268  Why don't we still do great music like in the ...
# 404269  How do you diagnose antisocial personality dis...
# 404270        What is the difference between who and how?
# 404271  Does Stalin have any grandchildren that are st...
# 404272  What are the best new car products or inventio...
# 404273    What happens if you put milk in a coffee maker?
# 404274  Will the next generation of parenting change o...
# 404275  In accounting, why do we debit expenses and cr...
# 404276                         What is copilotsearch.com?
# 404277                            What does analytics do?
# 404278          How did you prepare for AIIMS/NEET/AIPMT?
# 404279  What is the minimum time required to build a f...
# 404280  What are some outfit ideas to wear to a frat p...
# 404281  Why is Manaphy childish in Pokémon Ranger and ...
# 404282        How does a long distance relationship work?
# 404283  What do you think of the removal of the MagSaf...
# 404284         What does Jainism say about homosexuality?
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# 404287                                  What is one coin?
# 404288  What is the approx annual cost of living while...
# 404289              What is like to have sex with cousin?
#
#                                                 question2  is_duplicate  \
# 0       What is the step by step guide to invest in sh...             0
# 1       What would happen if the Indian government sto...             0
# 2       How can Internet speed be increased by hacking...             0
# 3       Find the remainder when [math]23^{24}[/math] i...             0
# 4                 Which fish would survive in salt water?             0
# 5       I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 6       What keeps childern active and far from phone ...             0
# 7               What should I do to be a great geologist?             1
# 8                   When do you use "&" instead of "and"?             0
# 9       How do I hack Motorola DCX3400 for free internet?             0
# 10      What are some of the things technicians can te...             0
# 11                 How can I see all my Youtube comments?             1
# 12                How can you make physics easy to learn?             1
# 13                 What was your first sexual experience?             1
# 14      What are the laws to change your status from a...             0
# 15      How will a Trump presidency affect the student...             1
# 16                          What does manipulation means?             1
# 17               How do guys feel after rejecting a girl?             0
# 18      Why do people ask Quora questions which can be...             1
# 19      Which is the best digital marketing institute ...             0
# 20            Why are rockets and boosters painted white?             1
# 21       What can I do to avoid being jealous of someone?             0
# 22                  Which question should I ask on Quora?             0
# 23      Where can I find a conversion chart for CC to ...             0
# 24       How many times a day do a clock’s hands overlap?             0
# 25      What are some tips on making it through the jo...             0
# 26                 What is the web application framework?             0
# 27               How do sports contribute to the society?             0
# 28              What is best way to ask for money online?             0
# 29      How one should know that he/she completely pre...             1
# ...                                                   ...           ...
# 404260           What is the best phone to buy below 15k?             0
# 404261  Who is the most popular character in the Game ...             1
# 404262                   How do I reset a Toshiba laptop?             0
# 404263  Why does CO2 contribute more to global warming...             0
# 404264         How do I make a safe and cheap power bank?             0
# 404265                  What should I eat to gain weight?             1
# 404266  My boyfriend says he deleted his Facebook Mess...             0
# 404267  What were the most important causes and effect...             1
# 404268       Should I raise my young child on 80's music?             0
# 404269  What Does It Feel Like to have antisocial pers...             0
# 404270      What is the difference between "&" and "and"?             0
# 404271  What was Joseph Stalin's 5 year plan? How did ...             0
# 404272  What are some mind-blowing vehicles tools that...             1
# 404273  What would happen if I put milk instead of wat...             1
# 404274  What kind of parents will the next generation ...             1
# 404275  What is a utilities expense in accounting? How...             0
# 404276                           What is ContenVania.com?             0
# 404277                   What are analytical people like?             0
# 404278  How did you prepare for the AIIMS UG entrance ...             0
# 404279  What is a cheaper and quicker way to build an ...             0
# 404280  What are some outfit ideas wear to a frat them...             1
# 404281  Why is Manaphy annoying in Pokemon ranger and ...             1
# 404282    How are long distance relationships maintained?             1
# 404283  What will the CPU upgrade to the 2016 Apple Ma...             0
# 404284  What does Jainism say about Gays and Homosexua...             1
# 404285  How many keywords are there in PERL Programmin...             0
# 404286         Is it true that there is life after death?             1
# 404287                                  What's this coin?             0
# 404288  I am having little hairfall problem but I want...             0
# 404289      What is it like to have sex with your cousin?             0
#
#                                       clean_q1_lemmatized  \
# 0       [what, be, the, step, by, step, guide, to, inv...
# 1       [what, be, the, story, of, kohinoor, koh, i, n...
# 2       [how, can, i, increase, the, speed, of, my, in...
# 3       [why, be, i, mentally, very, lonely, how, can,...
# 4       [which, one, dissolve, in, water, quickly, sug...
# 5       [astrology, i, be, a, capricorn, sun, cap, moo...
# 6                                 [should, i, buy, tiago]
# 7                   [how, can, i, be, a, good, geologist]
# 8                       [when, do, you, use, instead, of]
# 9       [motorola, company, can, i, hack, my, charter,...
# 10      [method, to, find, separation, of, slit, use, ...
# 11      [how, do, i, read, and, find, my, youtube, com...
# 12             [what, can, make, physic, easy, to, learn]
# 13      [what, be, your, first, sexual, experience, like]
# 14      [what, be, the, law, to, change, your, status,...
# 15      [what, would, a, trump, presidency, mean, for,...
# 16                         [what, do, manipulation, mean]
# 17      [why, do, girl, want, to, be, friend, with, th...
# 18      [why, be, so, many, quora, user, post, questio...
# 19      [which, be, the, best, digital, marketing, ins...
# 20                         [why, do, rocket, look, white]
# 21             [what, s, cause, someone, to, be, jealous]
# 22      [what, be, the, question, should, not, ask, on...
# 23                        [how, much, be, 30, kv, in, hp]
# 24      [what, do, it, mean, that, every, time, i, loo...
# 25      [what, be, some, tip, on, make, it, through, t...
# 26                           [what, be, web, application]
# 27      [do, society, place, too, much, importance, on...
# 28         [what, be, best, way, to, make, money, online]
# 29         [how, should, i, prepare, for, ca, final, law]
# ...                                                   ...
# 404260             [which, phone, be, best, under, 12000]
# 404261  [who, be, the, overall, most, popular, game, o...
# 404262   [how, do, you, troubleshoot, a, toshiba, laptop]
# 404263  [how, do, the, burning, of, fossil, fuel, cont...
# 404264  [be, it, safe, to, store, an, external, batter...
# 404265          [how, can, i, gain, weight, on, my, body]
# 404266  [what, be, the, green, dot, next, to, the, pho...
# 404267  [what, be, the, cause, of, the, fall, of, the,...
# 404268  [why, don, t, we, still, do, great, music, lik...
# 404269  [how, do, you, diagnose, antisocial, personali...
# 404270  [what, be, the, difference, between, who, and,...
# 404271  [do, stalin, have, any, grandchild, that, be, ...
# 404272  [what, be, the, best, new, car, product, or, i...
# 404273  [what, happen, if, you, put, milk, in, a, coff...
# 404274  [will, the, next, generation, of, parent, chan...
# 404275  [in, account, why, do, we, debit, expense, and...
# 404276                     [what, be, copilotsearch, com]
# 404277                          [what, do, analytics, do]
# 404278   [how, do, you, prepare, for, aiims, neet, aipmt]
# 404279  [what, be, the, minimum, time, require, to, bu...
# 404280  [what, be, some, outfit, idea, to, wear, to, a...
# 404281  [why, be, manaphy, childish, in, pok, mon, ran...
# 404282   [how, do, a, long, distance, relationship, work]
# 404283  [what, do, you, think, of, the, removal, of, t...
# 404284     [what, do, jainism, say, about, homosexuality]
# 404285  [how, many, keywords, be, there, in, the, rack...
# 404286  [do, you, believe, there, be, life, after, death]
# 404287                              [what, be, one, coin]
# 404288  [what, be, the, approx, annual, cost, of, live...
# 404289      [what, be, like, to, have, sex, with, cousin]
#
#                                       clean_q2_lemmatized  clean_lemm_wmd
# 0       [what, be, the, step, by, step, guide, to, inv...        0.640008
# 1       [what, would, happen, if, the, indian, governm...        2.436485
# 2       [how, can, internet, speed, be, increase, by, ...        1.564792
# 3       [find, the, remainder, when, math, 23, 24, mat...        3.826740
# 4          [which, fish, would, survive, in, salt, water]        2.969638
# 5       [i, be, a, triple, capricorn, sun, moon, and, ...        2.239106
# 6       [what, keep, childern, active, and, far, from,...        3.450202
# 7       [what, should, i, do, to, be, a, great, geolog...        0.845662
# 8                  [when, do, you, use, instead, of, and]        0.000000
# 9       [how, do, i, hack, motorola, dcx3400, for, fre...        1.746644
# 10      [what, be, some, of, the, thing, technician, c...        3.440657
# 11          [how, can, i, see, all, my, youtube, comment]        1.363920
# 12         [how, can, you, make, physic, easy, to, learn]        0.000000
# 13            [what, be, your, first, sexual, experience]        0.769736
# 14      [what, be, the, law, to, change, your, status,...        0.332179
# 15      [how, will, a, trump, presidency, affect, the,...        2.227544
# 16                         [what, do, manipulation, mean]        0.000000
# 17           [how, do, guy, feel, after, reject, a, girl]        1.141790
# 18      [why, do, people, ask, quora, question, which,...        1.607048
# 19      [which, be, the, best, digital, marketing, ins...        1.243737
# 20          [why, be, rocket, and, booster, paint, white]        1.876004
# 21      [what, can, i, do, to, avoid, be, jealous, of,...        1.060599
# 22           [which, question, should, i, ask, on, quora]        0.000000
# 23      [where, can, i, find, a, conversion, chart, fo...        3.619358
# 24      [how, many, time, a, day, do, a, clock, s, han...        1.839288
# 25      [what, be, some, tip, on, make, it, through, t...        0.517324
# 26           [what, be, the, web, application, framework]        1.131990
# 27         [how, do, sport, contribute, to, the, society]        1.987445
# 28      [what, be, best, way, to, ask, for, money, onl...        0.508318
# 29      [how, one, should, know, that, he, she, comple...        1.932466
# ...                                                   ...             ...
# 404260  [what, be, the, best, phone, to, buy, below, 15k]        1.133563
# 404261  [who, be, the, most, popular, character, in, t...        0.589729
# 404262            [how, do, i, reset, a, toshiba, laptop]        1.484371
# 404263  [why, do, co2, contribute, more, to, global, w...        1.861609
# 404264  [how, do, i, make, a, safe, and, cheap, power,...        2.500575
# 404265           [what, should, i, eat, to, gain, weight]        1.197648
# 404266  [my, boyfriend, say, he, delete, his, facebook...        2.881064
# 404267  [what, be, the, most, important, cause, and, e...        1.227089
# 404268  [should, i, raise, my, young, child, on, 80, s...        2.190450
# 404269  [what, do, it, feel, like, to, have, antisocia...        1.548333
# 404270     [what, be, the, difference, between, and, and]        0.000000
# 404271  [what, be, joseph, stalin, s, 5, year, plan, h...        2.464963
# 404272  [what, be, some, mind, blowing, vehicle, tool,...        2.148709
# 404273  [what, would, happen, if, i, put, milk, instea...        1.660881
# 404274  [what, kind, of, parent, will, the, next, gene...        1.228173
# 404275  [what, be, a, utilities, expense, in, account,...        2.396049
# 404276                       [what, be, contenvania, com]        0.000000
# 404277               [what, be, analytical, people, like]        3.993294
# 404278  [how, do, you, prepare, for, the, aiims, ug, e...        2.737844
# 404279  [what, be, a, cheap, and, quick, way, to, buil...        2.258292
# 404280  [what, be, some, outfit, idea, wear, to, a, fr...        0.650183
# 404281  [why, be, manaphy, annoy, in, pokemon, ranger,...        1.927350
# 404282  [how, be, long, distance, relationship, maintain]        0.714663
# 404283  [what, will, the, cpu, upgrade, to, the, 2016,...        1.784904
# 404284  [what, do, jainism, say, about, gay, and, homo...        1.115080
# 404285  [how, many, keywords, be, there, in, perl, pro...        1.227020
# 404286  [be, it, true, that, there, be, life, after, d...        0.870777
# 404287                              [what, s, this, coin]        1.644274
# 404288  [i, be, have, little, hairfall, problem, but, ...        3.630486
# 404289  [what, be, it, like, to, have, sex, with, your...        0.000000
#
# [404290 rows x 9 columns]

# %%
import util
util.save_feature(train, 'train', features_to_save, 'id')
util.save_feature(test, 'test', features_to_save, 'test_id')
